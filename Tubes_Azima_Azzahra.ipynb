# %% [markdown]
# <a href="https://colab.research.google.com/github/zimazahra/Pemrograman_Phython/blob/main/Tubes_Azima_Azzahra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ntl = lambda x: 10*np.log10(x)
ltn = lambda x: 10**(x/10)

def cos(frekuensi,tp,ht,highreceiver,d):
    if frekuensi in range(150,1501):
        Ca=69.55
        Cb=26.16
    elif frekuensi in range(1501,2001):
        Ca=46.3
        Cb=33.9
    
    if tp=='urban' :
        Cm=0
    elif tp=='suburban' :
        Cm= -2*((np.log10((frekuensi/28)**2))-5.4)
    elif tp=='open' :
        Cm= -4.78*(np.log10(frekuensi))+18.33*(np.log10(frekuensi))-40.94
    else :
        Cm='tp salah'
    
    ahighreceiver = (1.1*np.log10(frekuensi)-0.7)*highreceiver-(1.56*np.log10(frekuensi)-1.8)
    Lp = Ca+(Cb*np.log10(frekuensi))-(13.83*np.log(ht))-ahighreceiver+((44.9-6.55*np.log10(ht))*np.log10(d))-Cm
    
    return Lp

# %%
ht = 80
highreceiver = 1.5
dmin=300 
dmax=1000 
N = 200
ptr = 30
gtr = 10
gre = 2
bw = 5000
d=np.random.randint(dmin,dmax,N)

# %%
#fungsi daya terima, snr, kapasitas seluler
def dterima(ptr,pl,gtr,gre):
  ptr1 = ntl(ptr)
  daya = ptr - pl + gtr + gre
  daya1 = ltn(daya)
  return daya1

def snr(dterima,bw):
  noise = -174 + 10*np.log10(bw)
  noise1 = ltn(noise)
  snr = dterima/noise1
  return snr

def ks(snr,bw):
  snr1 = ltn(snr)
  ks = bw*np.log2(1+snr1)
  return ks

# %%
#daya terima f sama
def dterimaurban():
  f=1800 
  loc='urban'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  d_sort=d[np.argsort(d)]
  Urban_sort=dterimafix[np.argsort(d)]
  return d_sort,Urban_sort

def dterimaopen():
  f=1800 
  loc='open'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  d_sort=d[np.argsort(d)]
  Urban_sort=dterimafix[np.argsort(d)]
  return d_sort,Urban_sort

def dterimasuburban():
  f=1800 
  loc='suburban'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  d_sort=d[np.argsort(d)]
  Urban_sort=dterimafix[np.argsort(d)]
  return d_sort,Urban_sort
  
d11,pl11 = dterimaurban()
d12,pl12 = dterimaopen()
d13,pl13 = dterimasuburban()


#daya terima lokasi sama
def dterima700():
  f=700
  loc='urban'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  d_sort=d[np.argsort(d)]
  Urban_sort=dterimafix[np.argsort(d)]
  return d_sort,Urban_sort

def dterima900():
  f=900
  loc='urban'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  d_sort=d[np.argsort(d)]
  Urban_sort=dterimafix[np.argsort(d)]
  return d_sort,Urban_sort

def dterima1800():
  f=1800 
  loc='urban'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  d_sort=d[np.argsort(d)]
  Urban_sort=dterimafix[np.argsort(d)]
  return d_sort,Urban_sort

d21,pl21 = dterima700()
d22,pl22 = dterima900()
d23,pl23 = dterima1800()

# %%
plt.figure()
plt.plot(d11,pl11,'g', label='urban')
plt.plot(d12,pl12,'y', label='open')
plt.plot(d13,pl13,'r', label='suburban')
plt.legend()
plt.title('Daya Terima')
plt.xlabel('Jarak (m)')
plt.ylabel('Daya Terima (miliwatt)')
plt.show()

plt.figure()
plt.plot(d21,pl21,'g', label='700 Mhz')
plt.plot(d22,pl22,'y', label='900 Mhz')
plt.plot(d23,pl23,'r', label='1800 Mhz')
plt.legend()
plt.title('Daya Terima')
plt.xlabel('Jarak (m)')
plt.ylabel('Daya Terima (miliwatt)')
plt.show()

# %%
#signal to noise ratio f sama
def snrurban():
  f=1800 
  loc='urban'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  snrfix = snr(dterimafix,bw)
  d_sort=d[np.argsort(d)]
  Urban_sort=snrfix[np.argsort(d)]
  return d_sort,Urban_sort

def snropen():
  f=1800 
  loc='open'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  snrfix = snr(dterimafix,bw)
  d_sort=d[np.argsort(d)]
  Urban_sort=snrfix[np.argsort(d)]
  return d_sort,Urban_sort

def snrsuburban():
  f=1800 
  loc='suburban'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  snrfix = snr(dterimafix,bw)
  d_sort=d[np.argsort(d)]
  Urban_sort=snrfix[np.argsort(d)]
  return d_sort,Urban_sort

d11,pl11 = snrurban()
d12,pl12 = snropen()
d13,pl13 = snrsuburban()


#signal to noise ratio lokasi sama
def snr700():
  f=700 
  loc='urban'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  snrfix = snr(dterimafix,bw)
  d_sort=d[np.argsort(d)]
  Urban_sort=snrfix[np.argsort(d)]
  return d_sort,Urban_sort

def snr900():
  f=900 
  loc='urban'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  snrfix = snr(dterimafix,bw)
  d_sort=d[np.argsort(d)]
  Urban_sort=snrfix[np.argsort(d)]
  return d_sort,Urban_sort


def snr1800():
  f=1800 
  loc='urban'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  snrfix = snr(dterimafix,bw)
  d_sort=d[np.argsort(d)]
  Urban_sort=snrfix[np.argsort(d)]
  return d_sort,Urban_sort

d21,pl21 = snr700()
d22,pl22 = snr900()
d23,pl23 = snr1800()

# %%
plt.figure()
plt.plot(d11,pl11,'g', label='urban')
plt.plot(d12,pl12,'y', label='open')
plt.plot(d13,pl13,'r', label='suburban')
plt.legend()
plt.title('SNR')
plt.xlabel('Jarak (m)')
plt.ylabel('SNR (dB)')
plt.show()

plt.figure()
plt.plot(d21,pl21,'g', label='700 Mhz')
plt.plot(d22,pl22,'y', label='900 Mhz')
plt.plot(d23,pl23,'r', label='1800 Mhz')
plt.legend()
plt.title('SNR')
plt.xlabel('Jarak (m)')
plt.ylabel('SNR (dB)')
plt.show()

# %%
#kapasitas seluler f sama
def ksurban():
  f=1800 
  loc='urban'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  snrfix = snr(dterimafix,bw)
  ksfix = ks(snrfix,bw)
  d_sort=d[np.argsort(d)]
  Urban_sort=ksfix[np.argsort(d)]
  return d_sort,Urban_sort

def ksopen():
  f=1800 
  loc='open'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  snrfix = snr(dterimafix,bw)
  ksfix = ks(snrfix,bw)
  d_sort=d[np.argsort(d)]
  Urban_sort=ksfix[np.argsort(d)]
  return d_sort,Urban_sort

def kssuburban():
  f=1800 
  loc='suburban'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  snrfix = snr(dterimafix,bw)
  ksfix = ks(snrfix,bw)
  d_sort=d[np.argsort(d)]
  Urban_sort=ksfix[np.argsort(d)]
  return d_sort,Urban_sort

d11,pl11 = ksurban()
d12,pl12 = ksopen()
d13,pl13 = kssuburban()


#kapasitas seluler lokasi sama
def ks700():
  f=700 
  loc='urban'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  snrfix = snr(dterimafix,bw)
  ksfix = ks(snrfix,bw)
  d_sort=d[np.argsort(d)]
  Urban_sort=ksfix[np.argsort(d)]
  return d_sort,Urban_sort

def ks900():
  f=900 
  loc='urban'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  snrfix = snr(dterimafix,bw)
  ksfix = ks(snrfix,bw)
  d_sort=d[np.argsort(d)]
  Urban_sort=ksfix[np.argsort(d)]
  return d_sort,Urban_sort

def ks1800():
  f=1800 
  loc='urban'
  pl=cos(f,loc,ht,highreceiver,d)
  dterimafix = dterima(ptr,pl,gtr,gre)
  snrfix = snr(dterimafix,bw)
  ksfix = ks(snrfix,bw)
  d_sort=d[np.argsort(d)]
  Urban_sort=ksfix[np.argsort(d)]
  return d_sort,Urban_sort

d21,pl21 = ks700()
d22,pl22 = ks900()
d23,pl23 = ks1800()

# %%
plt.figure()
plt.plot(d11,pl11,'g', label='urban')
plt.plot(d12,pl12,'y', label='open')
plt.plot(d13,pl13,'r', label='suburban')
plt.legend()
plt.title('Kapasitas')
plt.xlabel('Jarak (m)')
plt.ylabel('Kapasitas (bps)')
plt.show()

plt.figure()
plt.plot(d21,pl21,'g', label='700 Mhz')
plt.plot(d22,pl22,'y', label='900 Mhz')
plt.plot(d23,pl23,'r', label='1800 Mhz')
plt.legend()
plt.title('Kapasitas')
plt.xlabel('Jarak (m)')
plt.ylabel('Kapasitas (bps)')
plt.show()
